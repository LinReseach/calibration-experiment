# %% [markdown]
# # add new colums(error,virtual_dot after calibration) to the original dataframe

# %%
## add new colums(error,) to the original dataframe
import os
import re
import pandas as pd
filename='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset.csv'
df=pd.read_csv(filename)
df=df.drop(columns=['arrowOri', 'Resp','fName','sampTime'])
#df[df.person_ID==1]
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/error_l2cs_cal/'

for i in range(21):
    fx=root+'error_p'+str(i+1)+'.csv'
    dfx=pd.read_csv(fx)['0']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==False)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'error_l2cs_cal']= dfx.tolist()[0:len(y)]
    
#df.loc[(df['person_ID']==9)&(df['4k']==False)]

root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/virtual_2d_l2cs_cal/'
for i in range(21):
    fx=root+'virtual_2d_p'+str(i+1)+'.csv'
    dfx_x=pd.read_csv(fx)['virtual2d_x']
    dfx_y=pd.read_csv(fx)['virtual2d_y']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==False)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'virtual_l2cs_cal_x']= dfx_x.tolist()[0:len(y)]
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'virtual_l2cs_cal_y']= dfx_y.tolist()[0:len(y)]
    
df.loc[(df['person_ID']==9)&(df['4k']==False)]
df
# Out:
#        dotNr  corrResp         Dot_xy  person_ID  height  glasses  pos_number  \
# 0          7      True      [0.0,0.0]         20   157.0     True           1
# 1          7      True      [0.0,0.0]         20   157.0     True           1
# 2          7      True      [0.0,0.0]         20   157.0     True           1
# 3          7      True      [0.0,0.0]         20   157.0     True           1
# 4          7      True      [0.0,0.0]         20   157.0     True           1
# ...      ...       ...            ...        ...     ...      ...         ...
# 41782      4      True  [921.6,504.0]         18   151.0     True           9
# 41783      4      True  [921.6,504.0]         18   151.0     True           9
# 41784      4      True  [921.6,504.0]         18   151.0     True           9
# 41785      4      True  [921.6,504.0]         18   151.0     True           9
# 41786      4      True  [921.6,504.0]         18   151.0     True           9
#
# ...

# %%
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/error_l2cs_cal/'
for i in [1,3,11,12,13,14,17,18,19,20]:
    fx=root+'error_4k_p'+str(i+1)+'.csv'
    dfx=pd.read_csv(fx)['0']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==True)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'error_l2cs_cal']= dfx.tolist()[0:len(y)]
    
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/virtual_2d_l2cs_cal/'
for i in [1,3,11,12,13,14,17,18,19,20]:
    fx=root+'virtual_2d_4k_p'+str(i+1)+'.csv'
    dfx_x=pd.read_csv(fx)['virtual2d_x']
    dfx_y=pd.read_csv(fx)['virtual2d_y']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==True)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'virtual_l2cs_cal_x']= dfx_x.tolist()[0:len(y)]
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'virtual_l2cs_cal_y']= dfx_y.tolist()[0:len(y)]

# %%
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/error_eth_cal/'

for i in range(21):
    fx=root+'error_p'+str(i+1)+'.csv'
    dfx=pd.read_csv(fx)['0']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==False)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'error_eth_cal']= dfx.tolist()[0:len(y)]
    
#df.loc[(df['person_ID']==9)&(df['4k']==False)]

root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/virtual_2d_eth_cal/'
for i in range(21):
    fx=root+'virtual_2d_p'+str(i+1)+'.csv'
    dfx_x=pd.read_csv(fx)['virtual2d_x']
    dfx_y=pd.read_csv(fx)['virtual2d_y']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==False)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'virtual_eth_cal_x']= dfx_x.tolist()[0:len(y)]
    df.loc[(df['person_ID']==i+1)&(df['4k']==False),'virtual_eth_cal_y']= dfx_y.tolist()[0:len(y)]

# %%
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/error_eth_cal/'
for i in [1,3,11,12,13,14,17,18,19,20]:
    fx=root+'error_4k_p'+str(i+1)+'.csv'
    dfx=pd.read_csv(fx)['0']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==True)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'error_eth_cal']= dfx.tolist()[0:len(y)]
    
root='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/processed_data/virtual_2d_eth_cal/'
for i in [1,3,11,12,13,14,17,18,19,20]:
    fx=root+'virtual_2d_4k_p'+str(i+1)+'.csv'
    dfx_x=pd.read_csv(fx)['virtual2d_x']
    dfx_y=pd.read_csv(fx)['virtual2d_y']
    y=df.loc[(df['person_ID']==i+1)&(df['4k']==True)] 
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'virtual_eth_cal_x']= dfx_x.tolist()[0:len(y)]
    df.loc[(df['person_ID']==i+1)&(df['4k']==True),'virtual_eth_cal_y']= dfx_y.tolist()[0:len(y)]

# %%
df
df['error_l2cs'].mean()
# Out:
# 10.965109225332007

# %%
file='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset_calibration_crossvalidation.csv'
df.dropna().to_csv(file)

# %%
df=df[(df['corrResp']==True)&(df['error_eth']<30)&(df['error_l2cs']<30)] 
df=df[df['person_ID'].isin(['2','4','12','13','14','15','18','19','20','21'])]
a=df[df['4k']==True][['error_eth','error_eth_cal','error_l2cs','error_l2cs_cal']].mean()
b=df[df['4k']==False][['error_eth','error_eth_cal','error_l2cs','error_l2cs_cal']].mean()
print((a[['error_eth']]-a['error_eth_cal'])/a['error_eth'])
print((a[['error_l2cs']]-a['error_l2cs_cal'])/a['error_l2cs'])
print((b[['error_eth']]-b['error_eth_cal'])/b['error_eth'])
print((b[['error_l2cs']]-b['error_l2cs_cal'])/b['error_l2cs'])
# Out:
# error_eth    0.190809
# dtype: float64
# error_l2cs    0.187104
# dtype: float64
# error_eth    0.167727
# dtype: float64
# error_l2cs    0.13104
# dtype: float64

# %% [markdown]
# ## get new dataset with correct dot_xy

# %%
import os
import re
import pandas as pd
filename='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset.csv'
df=pd.read_csv(filename)
# df=df[(df['corrResp']==True)&(df['error_eth']<30)&(df['error_l2cs']<30)]
# #df=df[df['person_ID'].isin(['2','4','12','13','14','15','18','19','20','21'])]
# df=df[df['person_ID'].isin(['13'])]
# df[(df['person_ID'].isin(['13']))&(df['4k']==True)].iloc[0]
dot13=df[(df['person_ID'].isin(['13']))&(df['4k']==True)]['Dot_xy']
dot15=df[(df['person_ID'].isin(['15']))&(df['4k']==True)]['Dot_xy']
dot15

df.loc[(df['person_ID']==13)&(df['4k']==False),'Dot_xy']=dot15.tolist()[0:1350]
df.loc[(df['person_ID']==13)&(df['4k']==True),'Dot_xy']=dot15.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==False),'Dot_xy']=dot13.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==True),'Dot_xy']=dot13.tolist()[0:1350]
df.loc[(df['person_ID']==13)&(df['4k']==False),'Dot_xy']

file='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset_newdotxy.csv'
df.to_csv(file)

# %%
import os
import re
import pandas as pd
filename='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset_newdotxy.csv'
df=pd.read_csv(filename)
etherror4k13=df[(df['person_ID'].isin(['13']))&(df['4k']==True)]['error_eth']
etherror4k15=df[(df['person_ID'].isin(['15']))&(df['4k']==True)]['error_eth']
etherrorno4k13=df[(df['person_ID'].isin(['13']))&(df['4k']==False)]['error_eth']
etherrorno4k15=df[(df['person_ID'].isin(['15']))&(df['4k']==False)]['error_eth']
df.loc[(df['person_ID']==13)&(df['4k']==False),'error_eth']=etherrorno4k15.tolist()[0:1350]
df.loc[(df['person_ID']==13)&(df['4k']==True),'error_eth']=etherror4k15.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==False),'error_eth']=etherrorno4k13.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==True),'error_eth']=etherror4k13.tolist()[0:1350]

vetherror4k13=df[(df['person_ID'].isin(['13']))&(df['4k']==True)]['virtual_eth']
vetherror4k15=df[(df['person_ID'].isin(['15']))&(df['4k']==True)]['virtual_eth']
vetherrorno4k13=df[(df['person_ID'].isin(['13']))&(df['4k']==False)]['virtual_eth']
vetherrorno4k15=df[(df['person_ID'].isin(['15']))&(df['4k']==False)]['virtual_eth']
df.loc[(df['person_ID']==13)&(df['4k']==False),'virtual_eth']=vetherrorno4k15.tolist()[0:1350]
df.loc[(df['person_ID']==13)&(df['4k']==True),'virtual_eth']=vetherror4k15.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==False),'virtual_eth']=vetherrorno4k13.tolist()[0:1350]
df.loc[(df['person_ID']==15)&(df['4k']==True),'virtual_eth']=vetherror4k13.tolist()[0:1350]
file='/Users/chenglinlin/ownCloud/BETA_AI_Gaze_Estimation_in_Human-Robot_Interaction (Projectfolder)/analized_data/analysis_dataset_neweth.csv'
df.to_csv(file)

# %%
df[(df['person_ID'].isin(['13']))&(df['4k']==False)].iloc[0]
# Out:
# Unnamed: 0                                                  22895
# dotNr                                                           9
# arrowOri                                                    right
# Resp                                                        right
# corrResp                                                     True
# fName                       2022_11_30_16_4_46_73783264_00001.jpg
# sampTime                                                  357.977
# Dot_xy                                               [0.0,-504.0]
# person_ID                                                      13
# height                                                        167
# glasses                                                      True
# pos_number                                                      1
# 4k                                                          False
# 3D_gaze         -0.1194273088749048,0.1258605888346895,-0.9848...
# ...
